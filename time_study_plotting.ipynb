# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'time_study.csv')
df
# Out:
#       True_Energy  delta_t  True_T  Trap_Energy  Waveform_Energy
# 0               5       28      40     6.584723        57.792706
# 1               5       28      40     6.584723        57.792706
# 2               5       28      40     6.584723        57.792706
# 3               5       28      40     6.584723        57.792706
# 4               5       39      44     5.880948        42.085686
# ...           ...      ...     ...          ...              ...
# 2475          100       49     156    98.245354       144.873633
# 2476          100       55     160    96.409650       145.756031
# 2477          100       55     160    96.409650       145.756031
# 2478          100       55     160    96.409650       145.756031
# 2479          100       55     160    96.409650       145.756031
#
# [2480 rows x 5 columns]

# %%
plt.hist2d(df["Trap_Energy"]*0.0408625 -0.16892, df["Waveform_Energy"]*0.0408625 -0.16892, bins=(100,100))
plt.xlim(0,5)
plt.ylim(0,6)
plt.show()

# %%
plt.scatter(df["Trap_Energy"]*0.0408625 -0.16892, df["True_T"]*8, c=df["delta_t"], cmap='Greens')
plt.xlim(0,5)
plt.colorbar()
plt.show()

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(df["Trap_Energy"]*0.0408625 -0.16892, df["True_T"]*8, df["delta_t"]*8 , c=df["delta_t"]*8, cmap='Greens')
plt.show()
